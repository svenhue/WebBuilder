# %%
import cv2
from pathlib import Path
from matplotlib import pyplot as plt
from IPython.core.display import HTML
from pdf2image import convert_from_path
import deepdoctection as dd


pdf_path = Path.cwd() / "exampledata/CV_SvenHuening.pdf"
images = convert_from_path(pdf_path)
images[0].save("exampledata/CV_SvenHuening.jpg", "JPEG")

image_path = Path.cwd()  / "exampledata/CV_SvenHuening.jpg"

image = cv2.imread(image_path.as_posix())
plt.figure(figsize = (25,17))
plt.axis('off')
#plt.imshow(image)


analyzer = dd.get_dd_analyzer(config_overwrite=["LANGUAGE='eng'"])
# Out:
# [1211 22:28.07 @dd.py:148]  INF  Config:
#  {'DEVICE': device(type='cpu'),
#  'LANGUAGE': 'eng',
#  'LAYOUT_LINK': {'CHILD_CATEGORIES': [], 'PARENTAL_CATEGORIES': []},
#  'LAYOUT_NMS_PAIRS': {'COMBINATIONS': None, 'PRIORITY': None, 'THRESHOLDS': None},
#  'LIB': 'PT',
#  'OCR': {'CONFIG': {'TESSERACT': 'dd/conf_tesseract.yaml'},
#          'USE_DOCTR': False,
#          'USE_TESSERACT': True,
#          'USE_TEXTRACT': False,
#          'WEIGHTS': {'DOCTR_RECOGNITION': {'PT': 'doctr/crnn_vgg16_bn/pt/crnn_vgg16_bn-9762b0b0.pt',
#                                            'TF': 'doctr/crnn_vgg16_bn/tf/crnn_vgg16_bn-76b7f2c6.zip'},
#                      'DOCTR_WORD': {'PT': 'doctr/db_resnet50/pt/db_resnet50-ac60cadc.pt',
#                                     'TF': 'doctr/db_resnet50/tf/db_resnet50-adcafc63.zip'}}},
#  'PDF_MINER': {'X_TOLERANCE': 3, 'Y_TOLERANCE': 3},
#  'PT': {'CELL': {'FILTER': None,
#                  'WEIGHTS': 'cell/d2_model_1849999_cell_inf_only.pt',
#                  'WEIGHTS_TS': 'cell/d2_model_1849999_cell_inf_only.ts'},
#         'ITEM': {'FILTER': None,
#                  'PAD': {'BOTTOM': 60, 'LEFT': 60, 'RIGHT': 60, 'TOP': 60},
#                  'WEIGHTS': 'item/d2_model_1639999_item_inf_only.pt',
#                  'WEIGHTS_TS': 'item/d2_model_1639999_item_inf_only.ts'},
#         'LAYOUT': {'FILTER': None,
#                    'PAD': {'BOTTOM': 60, 'LEFT': 60, 'RIGHT': 60, 'TOP': 60},
#                    'WEIGHTS': 'layout/d2_model_0829999_layout_inf_only.pt',
#                    'WEIGHTS_TS': 'layout/d2_model_0829999_layout_inf_only.ts'}},
#  'SEGMENTATION': {'ASSIGNMENT_RULE': 'ioa',
#                   'CELL_CATEGORY_ID': 12,
#                   'CELL_NAMES': [<CellType.HEADER>, <CellType.BODY>, <LayoutType.CELL>],
#                   'FULL_TABLE_TILING': True,
#                   'ITEM_NAMES': [<LayoutType.ROW>, <LayoutType.COLUMN>],
#                   'PUBTABLES_CELL_NAMES': [<CellType.SPANNING>, <CellType.ROW_HEADER>,
#                                            <CellType.COLUMN_HEADER>,
#                                            <CellType.PROJECTED_ROW_HEADER>, <LayoutType.CELL>],
#                   'PUBTABLES_ITEM_NAMES': [<LayoutType.ROW>, <LayoutType.COLUMN>],
#                   'PUBTABLES_SPANNING_CELL_NAMES': [<CellType.SPANNING>, <CellType.ROW_HEADER>,
#                                                     <CellType.COLUMN_HEADER>,
#                                                     <CellType.PROJECTED_ROW_HEADER>],
#                   'PUBTABLES_SUB_ITEM_NAMES': [<CellType.ROW_NUMBER>, <CellType.COLUMN_NUMBER>],
#                   'REMOVE_IOU_THRESHOLD_COLS': 0.001,
#                   'REMOVE_IOU_THRESHOLD_ROWS': 0.001,
#                   'STRETCH_RULE': 'equal',
#                   'SUB_ITEM_NAMES': [<CellType.ROW_NUMBER>, <CellType.COLUMN_NUMBER>],
#                   'TABLE_NAME': <LayoutType.TABLE>,
#                   'THRESHOLD_COLS': 0.4,
#                   'THRESHOLD_ROWS': 0.4},
#  'TEXT_CONTAINER': <LayoutType.WORD>,
#  'TEXT_ORDERING': {'BROKEN_LINE_TOLERANCE': 0.003,
#                    'FLOATING_TEXT_BLOCK_CATEGORIES': ['title', 'text', 'list'],
#                    'HEIGHT_TOLERANCE': 2.0,
#                    'INCLUDE_RESIDUAL_TEXT_CONTAINER': False,
#                    'LAYOUT_LINK': {'CHILD_CATEGORIES': None, 'PARENTAL_CATEGORIES': None},
#                    'PARAGRAPH_BREAK': 0.035,
#                    'STARTING_POINT_TOLERANCE': 0.005,
#                    'TEXT_BLOCK_CATEGORIES': ['title', 'text', 'list', 'cell', 'column_header',
#                                              'projected_row_header', 'spanning', 'row_header'],
#                    'USE_LAYOUT_LINK': False},
#  'TF': {'CELL': {'FILTER': None, 'WEIGHTS': 'cell/model-1800000_inf_only.data-00000-of-00001'},
#         'ITEM': {'FILTER': None, 'WEIGHTS': 'item/model-1620000_inf_only.data-00000-of-00001'},
#         'LAYOUT': {'FILTER': None, 'WEIGHTS': 'layout/model-800000_inf_only.data-00000-of-00001'}},
#  'USE_LAYOUT': True,
#  'USE_LAYOUT_LINK': False,
#  'USE_LAYOUT_NMS': False,
#  'USE_OCR': True,
#  'USE_PDF_MINER': False,
#  'USE_ROTATOR': False,
#  'USE_TABLE_REFINEMENT': True,
#  'USE_TABLE_SEGMENTATION': True,
#  'WORD_MATCHING': {'MAX_PARENT_ONLY': True,
#                    'PARENTAL_CATEGORIES': ['text', 'title', 'list', 'cell', 'column_header',
#                                            'projected_row_header', 'spanning', 'row_header'],
#                    'RULE': 'ioa',
#                    'THRESHOLD': 0.6}}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError:
#
# The above exception was the direct cause of the following exception:
#
# DependencyError                           Traceback (most recent call last)
# Cell In[9], line 21
#      17 plt.axis('off')
#      18 #plt.imshow(image)
# ---> 21 analyzer = dd.get_dd_analyzer(config_overwrite=["LANGUAGE='eng'"])
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\analyzer\dd.py:154, in get_dd_analyzer(reset_config_file, config_overwrite, path_config_file)
#     151 if tensorpack_available():
#     152     disable_tp_layer_logging()
# --> 154 return ServiceFactory.build_analyzer(cfg)
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\analyzer\factory.py:701, in ServiceFactory.build_analyzer(config)
#     698     word_service = ServiceFactory.build_doctr_word_detector_service(word_detector)
#     699     pipe_component_list.append(word_service)
# --> 701 ocr_detector = ServiceFactory.build_ocr_detector(config)
#     702 text_extraction_service = ServiceFactory.build_text_extraction_service(config, ocr_detector)
#     703 pipe_component_list.append(text_extraction_service)
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\analyzer\factory.py:344, in ServiceFactory.build_ocr_detector(config)
#     337 @staticmethod
#     338 def build_ocr_detector(config: AttrDict) -> Union[TesseractOcrDetector, DoctrTextRecognizer, TextractOcrDetector]:
#     339     """
#     340     Building OCR predictor
#     341
#     342     :param config: configuration object
#     343     """
# --> 344     return ServiceFactory._build_ocr_detector(config)
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\analyzer\factory.py:305, in ServiceFactory._build_ocr_detector(config)
#     303 if config.OCR.USE_TESSERACT:
#     304     ocr_config_path = get_configs_dir_path() / config.OCR.CONFIG.TESSERACT
# --> 305     return TesseractOcrDetector(
#     306         ocr_config_path,
#     307         config_overwrite=[f"LANGUAGES={config.LANGUAGE}"] if config.LANGUAGE is not None else None,
#     308     )
#     309 if config.OCR.USE_DOCTR:
#     310     weights = (
#     311         config.OCR.WEIGHTS.DOCTR_RECOGNITION.TF
#     312         if config.LIB == "TF"
#     313         else (config.OCR.WEIGHTS.DOCTR_RECOGNITION.PT)
#     314     )
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\extern\base.py:237, in PredictorBase.__new__(cls, *args, **kwargs)
#     236 def __new__(cls, *args, **kwargs):  # type: ignore # pylint: disable=W0613
# --> 237     requirements = cls.get_requirements()
#     238     name = cls.__name__ if hasattr(cls, "__name__") else cls.__class__.__name__
#     239     if not all(requirement[1] for requirement in requirements):
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\extern\tessocr.py:378, in TesseractOcrDetector.get_requirements(cls)
#     376 @classmethod
#     377 def get_requirements(cls) -> list[Requirement]:
# --> 378     return [get_tesseract_requirement()]
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\utils\file_utils.py:316, in get_tesseract_requirement()
#     312 def get_tesseract_requirement() -> Requirement:
#     313     """
#     314     Returns Tesseract requirement. The minimum version must be 3.05
#     315     """
# --> 316     if get_tesseract_version():
#     317         return "tesseract", True, _TESS_ERR_MSG
#     318     return "tesseract", False, _TESS_ERR_MSG
#
# File c:\Projects\WEBUI\WebUI\WebBuilder\AIServices\.venv\Lib\site-packages\deepdoctection\utils\file_utils.py:299, in get_tesseract_version()
#     292     output = subprocess.check_output(
#     293         [_TESS_PATH, "--version"],
#     294         stderr=subprocess.STDOUT,
#     295         env=environ,
#     296         stdin=subprocess.DEVNULL,
#     297     )
#     298 except OSError:
# --> 299     raise DependencyError(_TESS_ERR_MSG) from OSError
#     301 raw_version = output.decode("utf-8")
#     302 str_version, *_ = raw_version.lstrip(string.printable[10:]).partition(" ")
#
# DependencyError: Tesseract >=4.0 must be installed. Please follow the official installation instructions. https://tesseract-ocr.github.io/tessdoc/Installation.html
